# %%
#libraries
import pandas as pd
from matplotlib import pyplot as plt

# %%
# Set the display options for pandas

file_path = r'D:\Asaph Ray\Projects\marvel-superheroes-eda\data\charcters_stats.csv'

# %%
# Read the CSV file into a DataFrame
marvel = pd.read_csv(file_path)

# %%
marvel.head()
# Out:
#           Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0      3-D Man      good            50        31     43          32     25
# 1       A-Bomb      good            38       100     17          80     17
# 2   Abe Sapien      good            88        14     35          42     35
# 3     Abin Sur      good            50        90     53          64     84
# 4  Abomination       bad            63        80     53          90     55
#
#    Combat  Total
# 0      52    233
# 1      64    316
# 2      85    299
# 3      65    406
# 4      95    436

# %%
marvel.shape
# Out:
# (611, 9)

# %%
marvel[marvel['Alignment'] == 'good']
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 0            3-D Man      good            50        31     43          32
# 1             A-Bomb      good            38       100     17          80
# 2         Abe Sapien      good            88        14     35          42
# 3           Abin Sur      good            50        90     53          64
# 6        Adam Monroe      good            63        10     12         100
# ..               ...       ...           ...       ...    ...         ...
# 604            X-Man      good            88        53     53          95
# 606     Yellowjacket      good            88        10     12          28
# 607  Yellowjacket II      good            50        10     35          28
# 608             Ymir      good            50       100     27         100
# 609          Zatanna      good            75        10     23          28
#
#      Power  Combat  Total
# 0       25      52    233
# ...

# %%
marvel[marvel['Alignment'] == 'bad']
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 4       Abomination       bad            63        80     53          90
# 5           Abraxas       bad            88       100     83          99
# 11       Air-Walker       bad            50        85    100          85
# 16            Amazo       bad            75       100    100         100
# 17             Ammo       bad             1         1      1           1
# ..              ...       ...           ...       ...    ...         ...
# 586            Warp       bad            38        10     23          28
# 590       Weapon XI       bad             1         1      1           1
# 593  Willis Stryker       bad            38        16     23          28
# 605     Yellow Claw       bad             1         1      1           1
# 610            Zoom       bad            50        10    100          28
#
#      Power  Combat  Total
# 4       55      95    436
# 5      100      56    526
# ...

# %%
marvel[marvel['Intelligence']> 50]
# Out:
#              Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 2      Abe Sapien      good            88        14     35          42     35
# 4     Abomination       bad            63        80     53          90     55
# 5         Abraxas       bad            88       100     83          99    100
# 6     Adam Monroe      good            63        10     12         100     71
# 10     Agent Zero      good            75        28     38          80     72
# ..            ...       ...           ...       ...    ...         ...    ...
# 600  Wonder Woman      good            88       100     50         100     42
# 603          X-23      good            75        24     35          90     27
# 604         X-Man      good            88        53     53          95     92
# 606  Yellowjacket      good            88        10     12          28     12
# 609       Zatanna      good            75        10     23          28    100
#
#      Combat  Total
# ...

# %%
marvel['Alignment'].value_counts()
# Out:
# Alignment
# good       432
# bad        165
# neutral     11
# Name: count, dtype: int64

# %%
good=marvel[marvel['Alignment'] == 'good']

# %%
good.head()
# Out:
#           Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0      3-D Man      good            50        31     43          32     25
# 1       A-Bomb      good            38       100     17          80     17
# 2   Abe Sapien      good            88        14     35          42     35
# 3     Abin Sur      good            50        90     53          64     84
# 6  Adam Monroe      good            63        10     12         100     71
#
#    Combat  Total
# 0      52    233
# 1      64    316
# 2      85    299
# 3      65    406
# 6      64    320

# %%
good.sort_values(by= 'Alignment', ascending=False)
# Out:
#             Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0        3-D Man      good            50        31     43          32     25
# 406       Namora      good            50        85     42          42     41
# 417         Nova      good           100        85     67         101    100
# 416    Northstar      good            50        18     83          56     70
# 415  Nite Owl II      good             1         1      1           1      0
# ..           ...       ...           ...       ...    ...         ...    ...
# 196  Doctor Fate      good            81        16     25          80    100
# 193   Doc Samson      good            75        80     33          80     36
# 192   DL Hawkins      good            50        12     12          56     48
# 188     Deathlok      good            69        32     30          70     40
# 609      Zatanna      good            75        10     23          28    100
#
#      Combat  Total
# 0        52    233
# ...

# %%
good.sort_values(by= 'Speed', ascending=False)
# Out:
#                  Name Alignment  Intelligence  Strength  Speed  Durability  \
# 232          Flash IV      good            63        10    100          32
# 295           Impulse      good            50        10    100          60
# 304    Jack of Hearts      good            63        55    100          30
# 333            Krypto      good             9        80    100          90
# 85         Black Bolt      good            75        67    100          84
# ..                ...       ...           ...       ...    ...         ...
# 533        Super Moos      good             8         1      1          10
# 601            Wondra      good             1         1      1           1
# 134      Captain Atom      good             1         1      1           1
# 136      Captain Epic      good             1         1      1           1
# 137  Captain Mar-vell      good             1         1      1           1
#
#      Power  Combat  Total
# 232     59      48    312
# ...

# %%
max_speed_good=good[good['Speed']==100]

# %%
max_speed_good
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 85       Black Bolt      good            75        67    100          84
# 229         Flash I      good            63        10    100          50
# 230        Flash II      good            63        10    100          60
# 231       Flash III      good            63        10    100          60
# 232        Flash IV      good            63        10    100          32
# 295         Impulse      good            50        10    100          60
# 304  Jack of Hearts      good            63        55    100          30
# 333          Krypto      good             9        80    100          90
# 418            Nova      good            38        60    100         100
# 447     Quicksilver      good            63        28    100          60
# 525        Stardust      good            88        85    100         110
# 537        Superman      good           100       100    100         100
#
# ...

# %%
min_speed_good=good[good['Speed']==1]

# %%
min_speed_good
# Out:
#                  Name Alignment  Intelligence  Strength  Speed  Durability  \
# 7        Adam Strange      good             1         1      1           1
# 8           Agent  13      good             1         1      1           1
# 13       Alex Woolsly      good             1         1      1           1
# 15   Allan Quatermain      good             1         1      1           1
# 18     Ando Masahashi      good             1         1      1           1
# ..                ...       ...           ...       ...    ...         ...
# 580            Vulcan      good             1         1      1           1
# 584           Warbird      good             1         1      1           1
# 591       White Queen      good             1         1      1           1
# 595           Wiz Kid      good             1         1      1           1
# 601            Wondra      good             1         1      1           1
#
#      Power  Combat  Total
# 7        0       1      5
# ...

# %%
good.sort_values(by='Power', ascending=False)
# Out:
#             Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 589      Watcher      good           100        80     67          89    100
# 583  War Machine      good            63        80     63         100    100
# 547    Thor Girl      good            75        83     70          84    100
# 546         Thor      good            69       100     92         100    100
# 525     Stardust      good            88        85    100         110    100
# ..           ...       ...           ...       ...    ...         ...    ...
# 566     Vagabond      good             1         1      1           1      0
# 584      Warbird      good             1         1      1           1      0
# 580       Vulcan      good             1         1      1           1      0
# 579    Vision II      good             1         1      1           1      0
# 591  White Queen      good             1         1      1           1      0
#
#      Combat  Total
# 589      56    492
# ...

# %%
good.sort_values(by= 'Total', ascending=False)
# Out:
#                   Name Alignment  Intelligence  Strength  Speed  Durability  \
# 361  Martian Manhunter      good           100       100     96         100
# 537           Superman      good           100       100    100         100
# 525           Stardust      good            88        85    100         110
# 546               Thor      good            69       100     92         100
# 536          Supergirl      good            94        98     92         100
# ..                 ...       ...           ...       ...    ...         ...
# 89       Black Goliath      good             1         1      1           1
# 559      Tracy Strauss      good             1         1      1           1
# 566           Vagabond      good             1         1      1           1
# 33             Arachne      good             1         1      1           1
# 591        White Queen      good             1         1      1           1
#
#      Power  Combat  Total
# 361    100      85    581
# ...

# %%
good_max_power=good[good['Alignment'] == 'good']

# %%
good_max_power
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 0            3-D Man      good            50        31     43          32
# 1             A-Bomb      good            38       100     17          80
# 2         Abe Sapien      good            88        14     35          42
# 3           Abin Sur      good            50        90     53          64
# 6        Adam Monroe      good            63        10     12         100
# ..               ...       ...           ...       ...    ...         ...
# 604            X-Man      good            88        53     53          95
# 606     Yellowjacket      good            88        10     12          28
# 607  Yellowjacket II      good            50        10     35          28
# 608             Ymir      good            50       100     27         100
# 609          Zatanna      good            75        10     23          28
#
#      Power  Combat  Total
# 0       25      52    233
# ...

# %%
good_max_power.sort_values(by='Total', ascending=False)
# Out:
#                   Name Alignment  Intelligence  Strength  Speed  Durability  \
# 361  Martian Manhunter      good           100       100     96         100
# 537           Superman      good           100       100    100         100
# 525           Stardust      good            88        85    100         110
# 546               Thor      good            69       100     92         100
# 536          Supergirl      good            94        98     92         100
# ..                 ...       ...           ...       ...    ...         ...
# 89       Black Goliath      good             1         1      1           1
# 559      Tracy Strauss      good             1         1      1           1
# 566           Vagabond      good             1         1      1           1
# 33             Arachne      good             1         1      1           1
# 591        White Queen      good             1         1      1           1
#
#      Power  Combat  Total
# 361    100      85    581
# ...

# %%
plt.figure(figsize=(8, 5))
plt.bar(list(good_max_power['Name'])[0:5], list(good_max_power['Total'])[0:5], color='blue')
plt.xlabel('Superhero Names')
plt.ylabel('Total Stats')
plt.title('Top 5 Good Superheroes by Total Stats')
plt.show()

# %%
bad=marvel[marvel['Alignment'] == 'bad']

# %%
bad.head()
# Out:
#            Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 4   Abomination       bad            63        80     53          90     55
# 5       Abraxas       bad            88       100     83          99    100
# 11   Air-Walker       bad            50        85    100          85    100
# 16        Amazo       bad            75       100    100         100    100
# 17         Ammo       bad             1         1      1           1      0
#
#     Combat  Total
# 4       95    436
# 5       56    526
# 11      40    460
# 16     100    575
# 17       1      5

# %%
bad.sort_values(by='Speed', ascending=False)
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 11        Air-Walker       bad            50        85    100          85
# 16             Amazo       bad            75       100    100         100
# 535   Superboy-Prime       bad            94       100    100         100
# 610             Zoom       bad            50        10    100          28
# 242      General Zod       bad            94       100     96         100
# ..               ...       ...           ...       ...    ...         ...
# 521  Spider-Woman IV       bad             1         1      1           1
# 515   Spider-Carnage       bad             1         1      1           1
# 576         Violator       bad             1         1      1           1
# 590        Weapon XI       bad             1         1      1           1
# 605      Yellow Claw       bad             1         1      1           1
#
#      Power  Combat  Total
# 11     100      40    460
# ...

# %%
bad.sort_values(by='Combat', ascending=False)
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 16             Amazo       bad            75       100    100         100
# 475       Sabretooth       bad            55        53     25          90
# 449     Ra's Al Ghul       bad           100        28     32          42
# 4        Abomination       bad            63        80     53          90
# 52              Bane       bad            88        53     23          56
# ..               ...       ...           ...       ...    ...         ...
# 521  Spider-Woman IV       bad             1         1      1           1
# 515   Spider-Carnage       bad             1         1      1           1
# 576         Violator       bad             1         1      1           1
# 590        Weapon XI       bad             1         1      1           1
# 605      Yellow Claw       bad             1         1      1           1
#
#      Power  Combat  Total
# 16     100     100    575
# ...

# %%
bad.sort_values(by='Intelligence', ascending=False).head()
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 386  Mister Mxyzptlk       bad           113        10     12          14
# 122         Brainiac       bad           100        28     63          90
# 315            Joker       bad           100        10     12          56
# 194      Doctor Doom       bad           100        32     20         100
# 29        Apocalypse       bad           100       100     33         100
#
#      Power  Combat  Total
# 386    100      28    277
# 122     60      75    416
# 315     22      90    290
# 194     93      84    429
# 29     100      60    493

# %%
bad.sort_values(by='Power', ascending=False).head()
# Out:
#             Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 5        Abraxas       bad            88       100     83          99    100
# 16         Amazo       bad            75       100    100         100    100
# 11    Air-Walker       bad            50        85    100          85    100
# 29    Apocalypse       bad           100       100     33         100    100
# 26  Anti-Monitor       bad            88        90     38          90    100
#
#     Combat  Total
# 5       56    526
# 16     100    575
# 11      40    460
# 29      60    493
# 26      90    496

# %%
bad.sort_values(by='Total', ascending=False).head()
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 242     General Zod       bad            94       100     96         100
# 535  Superboy-Prime       bad            94       100    100         100
# 16            Amazo       bad            75       100    100         100
# 203        Dormammu       bad            88        95     83         100
# 201        Doomsday       bad            88        80     67         120
#
#      Power  Combat  Total
# 242     94      95    579
# 535    100      85    579
# 16     100     100    575
# 203    100      80    546
# 201    100      90    545

# %%
bad_max_power=bad.sort_values(by='Total', ascending=False)

# %%
plt.figure(figsize=(10,5))
plt.bar(list(bad_max_power['Name'])[0:5], list(bad_max_power['Total'])[0:5], color=['red', 'green', 'cyan', 'orange', 'purple'])
plt.xlabel('Superhero Names')
plt.ylabel('Total Stats')
plt.title('Top 5 Bad Superheroes by Total Stats')
plt.show()

# %%
#making a histogram of speed for good superheroes
plt.figure(figsize=(5,7))
plt.hist(good['Speed'], bins=10, color='blue', edgecolor='black')
plt.xlabel('Speed')
plt.title('Speed Distribution of Good Superheroes')
plt.show()

# %%
#histogram for combat of bad superheroes
plt.figure(figsize=(5,7))
plt.hist(bad['Combat'], bins=10, color='purple', edgecolor='white')
plt.title('Combat Distribution of Bad Superheroes')
plt.xlabel('Combat')
plt.show()

# %%
#histogram for combat of bad superheroes
plt.figure(figsize=(5,7))
plt.hist(good['Combat'], bins=10, color='cyan', edgecolor='white')
plt.title('Combat Distribution of Good Superheroes')
plt.xlabel('Combat')
plt.show()

# %%
marvel_total=marvel[['Name', 'Total']]

# %%
marvel_total.head()
# Out:
#           Name  Total
# 0      3-D Man    233
# 1       A-Bomb    316
# 2   Abe Sapien    299
# 3     Abin Sur    406
# 4  Abomination    436
